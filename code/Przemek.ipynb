# %%
# %matplotlib inline
import pandas as pd
import os
import numpy as np
import collections
import pickle
# import matplotlib.pyplot as plt

# %%
data = pd.read_pickle(os.path.join('..', 'data', 'xtrain.pkl'))

# %%
# pd.set_option('display.mpl_style', 'default') 
# pd.set_option('display.line_width', 5000) 
# pd.set_option('display.max_columns', 60)

# %%
data.keys()
data2 = {}

hash2 = lambda x: hash(x) % 10**6

def findFirstVal(s):
    for i in s:
        if i != None:
            return i

def transform_df(df, name):
    pass

def find_columns_type(df):
    result = {}
    for key, val in data.iteritems():
        for i in val:
            if i != None:
                result[key] = type(i)
                break 
    return result
       
def append_none(d):
    for k, v in d.iteritems():
        d[k].append(None)
        
def transform_dict(series, key_old):
    data = {}
    for item in series:
        if type(item) == dict:
            for k, v in item.iteritems():
                data[k] = []
    for item in series:
        if item == None:
            append_none(data)
        elif type(item) == dict:
            for k in data.keys():
                v = None if k not in item else item[k]
                if type(v) == dict:
                    data[k].append(hash2(None))
                elif type(v) == list:
                    data[k].append(hash2(None))
                elif type(v) in [int, float]:
                    data[k].append(v)
                else:
                    data[k].append(hash2(v))
    return {key_old + '++' + k : v for k, v in data.iteritems()}

def clean_val(df, columns_map):
    result = {}
    for key, val in data.iteritems():
        print key,
        if not key in columns_map or columns_map[key] == list:
            continue
        elif columns_map[key] in [int, float]:
            result[key] = val
        elif columns_map[key] == dict:
            result.update(transform_dict(val, key))
        else:
#             else columns_map[key] in [str, list]:
            result[key] = map(hash2, val)
    return result

columns_types = find_columns_type(data)
clean_df = clean_val(data, columns_types)
# Out:
# x72496 x32520 x46219 x97734 x98434 x13664 x83336 x48420 x97674 agent_type api_call_datetime browser browser_language browser_string browser_string_hash browser_string_mismatch browser_version cc_bin_number cc_bin_number_brand cc_bin_number_category cc_bin_number_geo cc_bin_number_org cc_bin_number_type cc_number_hash_assert_history cc_number_hash_first_seen cc_number_hash_last_event cc_number_hash_last_update cc_number_hash_result cc_number_hash_score cc_number_hash_worst_score cidr_number x21877 custom_count_1 custom_count_2 custom_count_3 custom_count_4 x87918 x68280 x31255 x85112 x18591 x35653 x75049 x76409 x80911 x96255 x60781 x23739 dns_ip_city dns_ip_geo dns_ip_isp dns_ip_latitude dns_ip_longitude dns_ip_organization dns_ip_region dns_ip_region_iso_code x5290 x5170 x5342 x5193 x92645 x31903 x94347 x82598 x40007 x13872 x59752 x14458 x85212 x54084 x3314 headers_name_value_hash headers_order_string_hash x10047 x80385 input_ip_assert_history input_ip_attributes input_ip_city input_ip_first_seen input_ip_geo input_ip_isp input_ip_last_event input_ip_last_update input_ip_latitude input_ip_longitude input_ip_organization input_ip_region input_ip_region_iso_code input_ip_result input_ip_score js_browser js_browser_string js_browser_string_hash js_fonts_hash js_fonts_number js_os mime_type_hash mime_type_number os x21202 x33709 x12964 x2801 x70617 x48486 x52094 x46567 x46591 x44170 x44566 x42973 x39150 x41009 x83032 x98509 x21215 x50289 x1384 x3370 x91746 x51274 x3168 profiling_datetime x42420 x66439 x50315 x66015 x51172 x92166 x92221 x58765 x64585 x67114 x3076 x63143 x26588 x38363 x26431 x42317 x97771 x73629 remote_desktop request_duration request_result review_status risk_rating x55586 x5600 x9486 x9789 x40163 x16453 session_id session_id_query_count x14739 x61305 x80025 time_zone time_zone_dst_offset transaction_currency x71910 x84525 x76585 x75714 x16584 x52116 x11958 x7971 x46383 x71182 x30901 x96316 x31318 x70806 x43300 x55037 x12050 x58838 x87611 id reference expiration_year expiration_month received_at bin bin_country client_status_code session_id transaction_amount transaction_currency application_id user_reference user_ip_address user_ip_country card_level supports_3d checked returns_not_authorized card_type country_code modified card_brand name tcp_mss tcp_tos tcp_ttl tcp_win tcp_os_name tcp_os_flavor headers_accept headers_connection headers_user_agent headers_content_type headers_content_length headers_accept_encoding headers_accept_language timeoftotalpageload timeofrequestresponse windowhistory navigatorvendor navigatorappname navigatorproduct navigatorappversion navigatorproductsub navigatorappcodename plugin screen feature language useragent donottrack timezoneoffset navigatorplatform navigatorlanguages navigatorjavaenabled navigatorcookieenabled timeformat parsed_user_agent flash_fonts flash_fields flash_devices dwell_time flight_time

# %%
print type(clean_df), len(clean_df)
# print clean_df.keys()
# print clean_df["dwell_time++min"]
# for k, v in clean_df.iteritems():
#     print k, len(v)
df = pd.DataFrame(clean_df)
print df.columns
with open(os.path.join('..','data', 'our_df.pickled'), 'w') as f:
    pickle.dump(df,f)
# Out:
# <type 'dict'> 337
# Index([             u'agent_type',          u'application_id',
#                            u'bin',             u'bin_country',
#                        u'browser',        u'browser_language',
#                 u'browser_string',     u'browser_string_hash',
#        u'browser_string_mismatch',         u'browser_version',
#        ...
#                         u'x92645',                  u'x94347',
#                          u'x9486',                  u'x96255',
#                         u'x97674',                  u'x97734',
#                         u'x97771',                   u'x9789',
#                         u'x98434',                  u'x98509'],
#       dtype='object', length=337)

# %%
a = []
dicts = []
innerinnerdicts = [0]
def clean(x):
#     print type(x[0])
    for i in x:
        if i != None:
            a.append(type(i))
            if type(i) == dict:
#                 dicts.append(i.keys())
                dicts.append({key : type(val) for key, val in i.iteritems()})
                for key, val in dicts[-1].iteritems():
                    if val == dict:
                        innerinnerdicts[0] += len(i[key])
#                 dicts.append()
            break
#     a.append(type(x[0]))
    return x
data2 = data.apply(clean)
print set(a)
print a
print
print collections.Counter(a)
print
for i in dicts:
    print i
l = dicts
print len([item for sublist in l for item in sublist])
print innerinnerdicts
# print dicts
# Out:
# set([<type 'list'>, <type 'dict'>, <type 'str'>, <type 'numpy.int64'>, <type 'float'>, <type 'bool'>, <type 'int'>, <type 'unicode'>, <class 'pandas.tslib.Timestamp'>])
# [<type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'numpy.int64'>, <type 'int'>, <type 'float'>, <type 'float'>, <class 'pandas.tslib.Timestamp'>, <type 'str'>, <type 'str'>, <type 'float'>, <type 'str'>, <type 'float'>, <type 'str'>, <type 'int'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>, <type 'float'>, <type 'float'>, <type 'float'>, <type 'float'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'float'>, <type 'float'>, <type 'float'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'dict'>, <type 'dict'>, <type 'dict'>, <type 'unicode'>, <type 'unicode'>, <type 'unicode'>, <type 'float'>, <type 'unicode'>, <type 'list'>, <type 'bool'>, <type 'bool'>, <type 'dict'>, <type 'list'>, <type 'dict'>, <type 'dict'>, <type 'dict'>, <type 'dict'>]
#
# Counter({<type 'str'>: 187, <type 'unicode'>: 19, <type 'float'>: 12, <type 'dict'>: 8, <type 'list'>: 2, <type 'bool'>: 2, <type 'int'>: 2, <type 'numpy.int64'>: 1, <class 'pandas.tslib.Timestamp'>: 1})
#
# {u'NavigatorMimeTypes': <type 'dict'>, u'NavigatorPlugins': <type 'dict'>}
# {u'orientation': <type 'dict'>, u'AvailableResolution': <type 'list'>, u'visibility': <type 'dict'>, u'availableSize': <type 'list'>, u'ViewportSize': <type 'list'>, u'ColorDepth': <type 'int'>, u'ScreenResolution': <type 'list'>}
# {u'geolocation': <type 'bool'>, u'inputPlaceholder': <type 'bool'>, u'iframeSrcDoc': <type 'bool'>, u'AAC': <type 'unicode'>, u'battery': <type 'bool'>, u'intl': <type 'bool'>, u'proximity': <type 'bool'>, u'videoCaptions': <type 'bool'>, u'videoWebm': <type 'unicode'>, u'xhrFormData': <type 'bool'>, u'MP3': <type 'unicode'>, u'progressElement': <type 'bool'>, u'videoPoster': <type 'bool'>, u'crypto': <type 'bool'>, u'batteryPromise': <type 'bool'>, u'videoTheora': <type 'unicode'>, u'canvas': <type 'bool'>, u'vibration': <type 'bool'>, u'iframeSandbox': <type 'bool'>, u'base64': <type 'bool'>, u'WebGlSupport': <type 'int'>, u'meterElement': <type 'bool'>, u'ambientlight': <type 'bool'>, u'datalist': <type 'bool'>, u'details': <type 'bool'>, u'broadcastChannel': <type 'bool'>, u'inputAutofocus': <type 'bool'>, u'videoElement': <type 'bool'>, u'webSockets': <type 'bool'>, u'svgInText': <type 'bool'>, u'videoH264': <type 'unicode'>, u'dragAndDrop': <type 'bool'>, u'timeElement': <type 'bool'>, u'undo': <type 'bool'>, u'xhrCrossDomain': <type 'bool'>, u'fileAPI': <type 'bool'>, u'beacon': <type 'bool'>, u'resourceTiming': <type 'bool'>, u'WAV': <type 'unicode'>, u'inputTypeColor': <type 'bool'>, u'microdata': <type 'bool'>, u'svg': <type 'bool'>, u'highResolutionTime': <type 'bool'>, u'xhrProgressEvents': <type 'bool'>, u'serviceWorker': <type 'bool'>, u'Vorbis': <type 'unicode'>, u'inputTypeNumber': <type 'bool'>, u'webWorkers': <type 'bool'>, u'inputTypeEmail': <type 'bool'>, u'history': <type 'bool'>, u'command': <type 'bool'>, u'formConstraintValidation': <type 'bool'>, u'textAreaPlaceholder': <type 'bool'>, u'audio': <type 'bool'>, u'fetch': <type 'bool'>, u'canvasTextAPI': <type 'bool'>, u'outputElement': <type 'bool'>}
# {u'TimeFormat': <type 'unicode'>, u'DateString': <type 'list'>, u'DateFormat': <type 'unicode'>}
# {u'Capabilities.language': <type 'unicode'>, u'Capabilities.hasEmbeddedVideo': <type 'bool'>, u'Capabilities.screenDPI': <type 'int'>, u'Capabilities.supports32BitProcesses': <type 'bool'>, u'Capabilities.hasAudio': <type 'bool'>, u'Capabilities.hasTLS': <type 'bool'>, u'Capabilities.screenResolutionY': <type 'int'>, u'Capabilities.hasPrinting': <type 'bool'>, u'Capabilities.hasIME': <type 'bool'>, u'Capabilities.hasAudioEncoder': <type 'bool'>, u'Capabilities.hasScreenPlayback': <type 'bool'>, u'Capabilities.maxLevelIDC': <type 'unicode'>, u'Capabilities.touchscreenType': <type 'unicode'>, u'Capabilities.hasStreamingVideo': <type 'bool'>, u'Capabilities.playerType': <type 'unicode'>, u'Capabilities.hasStreamingAudio': <type 'bool'>, u'Capabilities.hasAccessibility': <type 'bool'>, u'Capabilities.manufacturer': <type 'unicode'>, u'Capabilities.cpuArchitecture': <type 'unicode'>, u'Capabilities.hasMP3': <type 'bool'>, u'Capabilities.supports64BitProcesses': <type 'bool'>, u'Capabilities.pixelAspectRatio': <type 'int'>, u'Capabilities.screenColor': <type 'unicode'>, u'Capabilities.screenResolutionX': <type 'int'>, u'Capabilities.version': <type 'unicode'>, u'Capabilities.hasScreenBroadcast': <type 'bool'>, u'Capabilities.serverString': <type 'unicode'>, u'Capabilities.avHardwareDisable': <type 'bool'>, u'Capabilities.isEmbeddedInAcrobat': <type 'bool'>, u'Capabilities.localFileReadDisable': <type 'bool'>, u'Capabilities.os': <type 'unicode'>, u'Capabilities.isDebugger': <type 'bool'>, u'Capabilities.hasVideoEncoder': <type 'bool'>}
# {u'Microphone': <type 'unicode'>, u'Camera': <type 'unicode'>}
# {u'std': <type 'float'>, u'avg': <type 'float'>, u'median': <type 'float'>, u'len': <type 'int'>}
# {u'std': <type 'float'>, u'avg': <type 'float'>, u'median': <type 'float'>, u'len': <type 'int'>}
# 112
# [16]

# %%
data[['dwell_time', 'flight_time']][17235:17241]
# Out:
#                                               dwell_time                                        flight_time
# 17235  {u'std': 14.8108497144, u'min': 3.4020000021, ...  {u'std': 242.80230849, u'min': 0.466999990749,...
# 17236  {u'std': 89.2020954957, u'min': 15, u'max': 39...  {u'std': 217.778852734, u'min': -125, u'max': ...
# 17237  {u'std': 11.2284751715, u'min': 29.065, u'max'...  {u'std': 188.206963995, u'min': 33.505, u'max'...
# 17238  {u'std': 26.4459029156, u'min': 43.0, u'max': ...  {u'std': 238.916298924, u'min': -88.0, u'max':...
# 17239  {u'std': 9.88043298489, u'min': 12.04, u'max':...  {u'std': 259.942166616, u'min': 7.205, u'max':...
# 17240  {u'std': 19.5967302059, u'min': 65.0, u'max': ...  {u'std': 191.961451879, u'min': -64.005, u'max...

# %%
data['browser'].value_counts()[:10].plot(kind='bar')

# %%
data[data['browser'] == "Chrome"]["browser"].values
# Out:
# array(['Chrome', 'Chrome', 'Chrome', ..., 'Chrome', 'Chrome', 'Chrome'], dtype=object)

# %%
data2
# Out:
# x72496                           None
# x32520                           None
# x46219                           None
# x97734                           None
# x98434                           None
# x13664                           None
# x83336                           None
# x48420                           None
# x97674                           None
# agent_type                       None
# api_call_datetime                None
# browser                          None
# browser_language                 None
# browser_string                   None
# browser_string_hash              None
# browser_string_mismatch          None
# browser_version                  None
# cc_bin_number                    None
# cc_bin_number_brand              None
# cc_bin_number_category           None
# cc_bin_number_geo                None
# cc_bin_number_org                None
# cc_bin_number_type               None
# cc_number_hash_assert_history    None
# cc_number_hash_first_seen        None
# cc_number_hash_last_event        None
# cc_number_hash_last_update       None
# cc_number_hash_result            None
# cc_number_hash_score             None
# cc_number_hash_worst_score       None
#                                  ...
# headers_content_length           None
# headers_accept_encoding          None
# headers_accept_language          None
# timeoftotalpageload              None
# timeofrequestresponse            None
# windowhistory                    None
# navigatorvendor                  None
# navigatorappname                 None
# navigatorproduct                 None
# navigatorappversion              None
# navigatorproductsub              None
# navigatorappcodename             None
# plugin                           None
# screen                           None
# feature                          None
# language                         None
# useragent                        None
# donottrack                       None
# timezoneoffset                   None
# navigatorplatform                None
# navigatorlanguages               None
# navigatorjavaenabled             None
# navigatorcookieenabled           None
# timeformat                       None
# parsed_user_agent                None
# flash_fonts                      None
# flash_fields                     None
# flash_devices                    None
# dwell_time                       None
# flight_time                      None
# dtype: object

# %%
data[0:10]
# Out:
#   x72496 x32520      x46219 x97734      x98434      x13664     x83336 x48420 x97674        agent_type api_call_datetime browser                        browser_language                                     browser_string               browser_string_hash browser_string_mismatch browser_version cc_bin_number cc_bin_number_brand cc_bin_number_category cc_bin_number_geo               cc_bin_number_org cc_bin_number_type cc_number_hash_assert_history cc_number_hash_first_seen cc_number_hash_last_event cc_number_hash_last_update cc_number_hash_result cc_number_hash_score cc_number_hash_worst_score     ...     headers_content_length headers_accept_encoding headers_accept_language timeoftotalpageload timeofrequestresponse windowhistory navigatorvendor navigatorappname navigatorproduct navigatorappversion navigatorproductsub navigatorappcodename plugin screen feature language useragent donottrack timezoneoffset navigatorplatform navigatorlanguages navigatorjavaenabled navigatorcookieenabled timeformat parsed_user_agent                                        flash_fonts                                       flash_fields                                      flash_devices dwell_time flight_time
# 0   None   None  2016-01-30   None  2016-02-01  2016-02-01    success      0      0    browser_mobile              None    None                                   en-US  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 6 Bui...  6e59e1b9069a91ba082fae76db1963f2                    None            None        434769                VISA                CLASSIC                US             JPMORGAN CHASE BANK              DEBIT                          None                2016-01-30                2016-02-01                 2016-02-01               success                    0                          0     ...                       None                    None                    None                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None                                               None                                               None                                               None       None        None
# 1   None   None        None   None        None        None  not found   None   None  browser_computer              None    None                          en-US,en;q=0.8  Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...  ffc03cf4cff9e192501dee13654f43a8                    None            None        533248          MASTERCARD                PREPAID                US                   COMERICA BANK              DEBIT                          None                      None                      None                       None             not found                 None                       None     ...                                gzip, deflate, sdch          en-US,en;q=0.8                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None  [Aharoni, Aldhabi, Andalus, Angsana New, Angsa...  {u'Capabilities.language': u'en', u'Capabiliti...               {u'Microphone': u'', u'Camera': u''}       None        None
# 2   None   None  2015-12-04   None  2016-02-01  2016-02-01    success      0      0  browser_computer              None    None                          en-US,en;q=0.8  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...  b241fa4a919c1a7c7b01b9c57dfa9bb9                    None            None        418646                VISA                CLASSIC                US                       U.S. BANK              DEBIT                          None                2015-12-04                2016-02-01                 2016-02-01               success                    0                          0     ...                                gzip, deflate, sdch          en-US,en;q=0.8                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None  [Agency FB, Aharoni, Aldhabi, Algerian, Andalu...  {u'Capabilities.language': u'en', u'Capabiliti...             {u'Microphone': u' ', u'Camera': u' '}       None        None
# 3   None   None        None   None        None        None  not found   None   None  browser_computer              None    None                          en-US,en;q=0.8  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...  13fe741da160361b3ae3b6ded1e92250                    None            None        545958          MASTERCARD               STANDARD                US                 BMO HARRIS BANK              DEBIT                          None                2015-12-30                2016-02-01                 2016-02-01               success                    0                          0     ...                       None                    None                    None                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None                                               None                                               None                                               None       None        None
# 4   None   None  2014-09-28   None  2016-02-01  2016-02-01    success      0      0  browser_computer              None    None                          en-US,en;q=0.8  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...  15a1c2ad77a4f7193d30e00ad616dd76                    None            None        527267          MASTERCARD                   None                US    FIRST CITIZENS NATIONAL BANK             CREDIT                          None                2015-09-15                2016-02-01                 2016-02-01               success                    0                          0     ...                                gzip, deflate, gzip          en-US,en;q=0.8                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None  [Albany AMT, AR BERKLEY, AR BLANCA, AR BONNIE,...  {u'Capabilities.language': u'en', u'Capabiliti...             {u'Microphone': u' ', u'Camera': u' '}       None        None
# 5   None   None  2015-06-25   None  2016-02-01  2016-02-01    success      0      0  browser_computer              None    None     fr-FR,fr;q=0.8,en-US;q=0.6,en;q=0.4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  2f4695c5cc6685ac05e383fb7004c5b1                    None            None        472409                VISA                CLASSIC                CA                            None              DEBIT                          None                      None                      None                       None             not found                 None                       None     ...                       None                    None                    None                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None                                               None                                               None                                               None       None        None
# 6   None   None  2016-01-28   None  2016-02-01  2016-02-01    success      0      0  browser_computer              None    None                          en-US,en;q=0.8  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.3...  c812574c8ae9b5bde75f723aa1e82e54                    None            None        456534                VISA                PREPAID                US                    BANCORP BANK              DEBIT                          None                      None                      None                       None             not found                 None                       None     ...                                gzip, deflate, sdch          en-US,en;q=0.8                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None  [Aharoni, Andalus, Angsana New, AngsanaUPC, AR...  {u'Capabilities.language': u'en', u'Capabiliti...               {u'Microphone': u'', u'Camera': u''}       None        None
# 7   None   None  2016-02-01   None  2016-02-01  2016-02-01    success      0      0  browser_computer              None    None                          en-US,en;q=0.5  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:43.0) G...  9db1e73107cd717e7b5a1ffa9d8049e8                    None            None        532737          MASTERCARD                   None                AU  COMMONWEALTH BANK OF AUSTRALIA              DEBIT                          None                2016-02-01                2016-02-01                 2016-02-01               success                    0                          0     ...                                      gzip, deflate          en-US,en;q=0.5                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None  [Aharoni, Andalus, Angsana New, AngsanaUPC, Ap...  {u'Capabilities.language': u'en', u'Capabiliti...  {u'Microphone': u'Headset Microphone (2- Micro...       None        None
# 8   None   None        None   None        None        None  not found   None   None  browser_computer              None    None  en-CA,en-GB;q=0.8,en-US;q=0.6,en;q=0.4  Mozilla/5.0 (Linux; Android 5.1.1; SM-G530W Bu...  ca1df7bff95cd6119f8982e79c8c6167                    None            None        421402                VISA                PREPAID                CA         CITIZENS BANK OF CANADA              DEBIT                          None                      None                      None                       None             not found                 None                       None     ...                       None                    None                    None                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None                                               None                                               None                                               None       None        None
# 9   None   None        None   None        None        None  not found   None   None    browser_mobile              None    None                                   en-au  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2_1 like ...  b9ea8dd5dc63e45cacbc3bcd3f6ba79b                    None            None        516361          MASTERCARD               STANDARD                AU     WESTPAC BANKING CORPORATION              DEBIT                          None                      None                      None                       None             not found                 None                       None     ...                                      gzip, deflate                   en-au                None                  None          None            None             None             None                None                None                 None   None   None    None     None      None       None           None              None               None                 None                   None       None              None                                               None                                               None                                               None       None        None
#
# [10 rows x 243 columns]
